# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df02 = pd.read_pickle("/content/drive/MyDrive/Colab/JAWAD/Updated_Model_New_Data/VALIDATION/02-01-2023/02-01-2023.pkl")
df03 = pd.read_pickle("/content/drive/MyDrive/Colab/JAWAD/Updated_Model_New_Data/VALIDATION/03-01-2023/03-01-2023.pkl")
df04 = pd.read_pickle("/content/drive/MyDrive/Colab/JAWAD/Updated_Model_New_Data/VALIDATION/04-01-2023/04-01-2023.pkl")

# %%
df02.head()
# Out:
#                   Time  Predictions   GHI
# 0  2023-01-02 08:12:00     3.484753  2.80
# 1  2023-01-02 08:13:00     3.484753  3.15
# 2  2023-01-02 08:14:00     3.484753  3.40
# 3  2023-01-02 08:15:00     3.948805  3.67
# 4  2023-01-02 08:16:00     3.948805  3.96

# %%
df03.head()
# Out:
#                   Time  Predictions   GHI
# 0  2023-01-03 08:11:00     6.690637  3.56
# 1  2023-01-03 08:12:00     7.252461  3.85
# 2  2023-01-03 08:13:00     8.237903  4.31
# 3  2023-01-03 08:14:00     7.928820  4.56
# 4  2023-01-03 08:15:00     7.948705  5.28

# %%
df04 = df04.drop(df04.columns[[1,2,3,4,5,6,7,8,9]], axis=1) 
df04.head()
# Out:
#                   Time  Predictions   GHI
# 0  2023-01-04 08:11:00     5.639696  7.54
# 1  2023-01-04 08:12:00     5.681774  7.44
# 2  2023-01-04 08:13:00     5.746583  7.25
# 3  2023-01-04 08:14:00     5.746583  7.17
# 4  2023-01-04 08:15:00     5.746583  6.98

# %%
merge = pd.concat([df02,df03,df04])
#Output = pd.concat([pd.read_pickle('/content/drive/MyDrive/Colab/JAWAD/Updated_Model_New_Data/VALIDATION/020304-01-2023/'+x) for x in os.listdir('location')])
merge
# Out:
#                     Time  Predictions   GHI
# 0    2023-01-02 08:12:00     3.484753  2.80
# 1    2023-01-02 08:13:00     3.484753  3.15
# 2    2023-01-02 08:14:00     3.484753  3.40
# 3    2023-01-02 08:15:00     3.948805  3.67
# 4    2023-01-02 08:16:00     3.948805  3.96
# ..                   ...          ...   ...
# 476  2023-01-04 16:08:00     5.451720  1.49
# 477  2023-01-04 16:09:00     5.451720  1.80
# 478  2023-01-04 16:10:00     5.451720  0.95
# 479  2023-01-04 16:11:00     5.451720  1.28
# 480  2023-01-04 16:12:00     5.451720  1.31
#
# [1441 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 300

merge.plot(x = 'Time', y=["Predictions", "GHI"], kind="line", figsize=(20, 6))

plt.xlabel('Time')
plt.ylabel('GHI in W/m²')
plt.xticks( rotation=12 )
plt.show()

# %%
rmse = ((merge["Predictions"] - merge["GHI"]) ** 2).mean() ** .5
print("Root Mean Squared Error :", rmse)
# Out:
# Root Mean Squared Error : 7.987851392547023
